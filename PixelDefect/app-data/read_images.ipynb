# %%
import argparse
import numpy as np
import rasterio
import requests
from matplotlib import pyplot as plt
import os

# %%
with rasterio.open('../results/crop_1_0_corr.tif') as src:
            restored_img = src.read()

plt.imshow(np.transpose(restored_img[:-1], axes=[1, 2, 0]) // 255 * 6)
plt.show()
# Out:
# C:\Users\Ilia\AppData\Roaming\Python\Python310\site-packages\rasterio\__init__.py:317: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
